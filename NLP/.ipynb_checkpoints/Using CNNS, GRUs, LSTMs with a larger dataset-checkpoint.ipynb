# %% [markdown]
# ### SetUp

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt
import os
import string

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
keras = tf.keras

tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# #### Load Dataset

# %%
dataset, info = tfds.load("glue/sst2", with_info = True)
print(info.features)
print(info.features['label'].num_classes)
print(info.features['label'].names)
# Out:
# FeaturesDict({
#     'idx': int32,
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     'sentence': Text(shape=(), dtype=string),
# })
# 2
# ['negative', 'positive']

# %% [markdown]
# #### Get the train and test Dataset

# %%
dataset_train, dataset_test = dataset['train'], dataset['test']
dataset_train
# Out:
# <_PrefetchDataset element_spec={'idx': TensorSpec(shape=(), dtype=tf.int32, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None), 'sentence': TensorSpec(shape=(), dtype=tf.string, name=None)}>

# %%
# print some entries
for example in dataset_train.take(2):
    review, label = example['sentence'], example['label']
    print("Review: ",str(review.numpy()))
    print("Label: ",label.numpy())
# Out:
# Review:  b'for the uninitiated plays better on video with the sound '
# Label:  0
# Review:  b'like a giant commercial for universal studios , where much of the action takes place '
# Label:  0
# 2024-03-15 22:45:09.450478: W tensorflow/core/kernels/data/cache_dataset_ops.cc:854] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
print(f"Train length: {len(dataset_train)}")
print(f"Test length: {len(dataset['test'])}")
# Out:
# Train length: 67349
# Test length: 1821

# %%
reviews = []
labels = []

train_reviews = []
train_labels = []

test_reviews = []
test_labels = []

for item in dataset_train.take(-1).shuffle(100000):
    reviews.append(str(item['sentence'].numpy()))
    labels.append(item['label'].numpy())
    
len_reviews = len(reviews)
print(f"No. of reviews examples: {len_reviews}")

split = int(len_reviews * 0.8)

train_reviews = reviews[:split]
train_labels = labels[:split]

test_reviews = reviews[split:]
test_labels = labels[split:]

# print some examples
print(f"No of train examples: {len(train_reviews)}")
for i in range(1, 4):
    print("Review: ",train_reviews[i])
    print("Label: ",train_labels[i])
print("\n\n")



"""
for item in dataset_test.take(1000):
    review, label = item['sentence'], item['label']
    test_reviews.append(str(review.numpy()))
    test_labels.append(label.numpy())
"""
print(f"No of test example: {len(test_reviews)}")
for i in range(30, 34):
    print("Review: ",test_reviews[i])
    print("Label: ",test_labels[i])
# Out:
# No. of reviews examples: 67349
# No of train examples: 53879
# Review:  b'a pretentious and '
# Label:  0
# Review:  b"that this likable movie is n't more accomplished "
# Label:  1
# Review:  b"a waterlogged version of ` fatal attraction ' for the teeny-bopper set ... a sad , soggy potboiler that wastes the talents of its attractive young leads "
# Label:  0
#
#
#
# No of test example: 13470
# Review:  b'marshall puts a suspenseful spin on standard horror flick formula . '
# Label:  1
# Review:  b'of lazy humor '
# Label:  1
# Review:  b'narc is all menace and atmosphere . '
# Label:  0
# Review:  b'moronic as some campus '
# Label:  0

# %% [markdown]
# ### Tokenize the words and sequence the sentence

# %%
vocab_size = 4000
embedding_dim = 16
max_length = 50
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"

tokenizer = Tokenizer(num_words = vocab_size, oov_token = oov_tok)
 'cinema': 196, 'less': 197, 'documentary': 198, 'romantic': 199, 'back': 200, 'material': 201, "'ve": 202, 'far': 203, 'itself': 204, 'might': 205, 'original': 206, 'before': 207, 'compelling': 208, 'watching': 209, 'worth': 210, 'seen': 211, 'right': 212, 'almost': 213, 'rather': 214, 'after': 215, 'visual': 216, 'years': 217, 'our': 218, 'piece': 219, 'had': 220, 'moving': 221, 'between': 222, 'ca': 223, 'these': 224, 'me': 225, 'scenes': 226, 'were': 227, 'my': 228, 'things': 229, "b'for": 230, 'art': 231, 'fascinating': 232, 'emotional': 233, 'full': 234, 'american': 235, 'take': 236, 'style': 237, 'music': 238, 'direction': 239, 'care': 240, 'quite': 241, 'find': 242, 'here': 243, 'least': 244, 'anything': 245, 'seem': 246, 'making': 247, 'together': 248, "b'one": 249, "'ll": 250, 'going': 251, 'kids': 252, 'star': 253, 'experience': 254, 'history': 255, 'dull': 256, 'young': 257, 'half': 258, 'times': 259, 'come': 260, 'thing': 261, 'lot': 262, 'sweet': 263, 'special': 264, 'comic': 265, 'yet': 266, 'laughs': 267, 'entertainment': 268, "b'be": 269, 'seems': 270, 'away': 271, 'part': 272, 'ultimately': 273, 'why': 274, 'high': 275, 'bit': 276, 'enjoyable': 277, 'genre': 278, 'works': 279, 'him': 280, 'go': 281, 'again': 282, 'worst': 283, 'three': 284, 'video': 285, 'perfect': 286, 'theater': 287, 'beautiful': 288, 'low': 289, 'point': 290, 'subject': 291, 'keep': 292, 'sometimes': 293, "b'most": 294, 'same': 295, 'idea': 296, 'comes': 297, 'where': 298, 'smart': 299, 'give': 300,  ...

# %% [markdown]
# ### Pad the sequences

# %%
train_seq = tokenizer.texts_to_sequences(train_reviews)
train_padded = pad_sequences(train_seq, padding = padding_type,
                            truncating = trunc_type, maxlen = max_length)

test_seq = tokenizer.texts_to_sequences(test_reviews)
test_padded = pad_sequences(test_seq, padding = padding_type,
                           maxlen = max_length, truncating = trunc_type)

train_labels_final = np.array(train_labels)
test_labels_final = np.array(test_labels)
train_labels_final
# Out:
# array([1, 0, 1, ..., 0, 0, 1])

# %% [markdown]
# ### Create the model using an Embedding

# %%
model = keras.Sequential([
    keras.layers.Embedding(vocab_size, embedding_dim, input_length = max_length),
    keras.layers.GlobalAveragePooling1D(),
    keras.layers.Dense(6, activation = 'relu'),
    keras.layers.Dense(1, activation = 'sigmoid')
])

model.compile(loss = 'binary_crossentropy',
         optimizer = 'adam',
         metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 16)            64000
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 6)                 102
#
#  dense_1 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 64109 (250.43 KB)
# Trainable params: 64109 (250.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ####
# %% [markdown]
# ### Plot the accuracy and loss

# %%
def plot_graphs(history, string):
    val_string = f"val_{string}"
    
    plt.plot(history.history[string])
    plt.plot(history.history[val_string])
    plt.ylabel(string.capitalize())
    plt.xlabel("Epochs")
    plt.legend([string, val_string])
    plt.show()

plot_graphs(history, "loss")
plot_graphs(history, "accuracy")

# %% [markdown]
# ### Function to predict some sentiment of reviews

# %%
review1 = """I loved this movie"""
review2 = """that was the worst movie I've ever seen"""
review3 = """too much violence even for a bond film"""
review4 = """a captivating recounting of a cherished myth"""

new_reviews = [review1, review2, review3, review4]

# %%
def predict_reviews(model, reviews):
    padding_type = "post"
    review_sequences = tokenizer.texts_to_sequences(reviews)
    review_padded = pad_sequences(review_sequences, maxlen = max_length,
                                 padding = padding_type)
    
    pred_labels = model.predict(review_padded)
    for _ in range(len(pred_labels)):
        print(reviews[_])
        print(pred_labels[_], end = "\n\n")
predict_reviews(model, new_reviews)
# Out:
# 1/1 [==============================] - 0s 132ms/step
# I loved this movie
# [0.9882387]
#
# that was the worst movie I've ever seen
# [0.01604736]
#
# too much violence even for a bond film
# [0.03413291]
#
# a captivating recounting of a cherished myth
# [0.98885965]

# %% [markdown]
# ### Define a function to train and show the results of models with different layers

# %%
def fit_model_and_show_results(model, reviews):
    model.summary()
    hist = model.fit(train_padded, train_labels_final, epochs = EPOCHS,
                    validation_data = (test_padded, test_labels_final))
    plot_graphs(hist, "accuracy")
    plot_graphs(hist, "loss")
    predict_reviews(model, reviews)

# %% [markdown]
# ### Use a CNN

# %%
model_cnn = keras.Sequential([
    keras.layers.Embedding(vocab_size, embedding_dim, input_length = max_length),
    keras.layers.Conv1D(128, 5, activation = 'relu'),
    keras.layers.GlobalMaxPooling1D(),
    keras.layers.Dense(6, activation = 'relu'),
    keras.layers.Dense(1, activation = 'sigmoid')
])
model_cnn.compile(loss = keras.losses.BinaryCrossentropy(),
             optimizer = keras.optimizers.Adam(),
             metrics = ['accuracy'])
fit_model_and_show_results(model_cnn, new_reviews)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 50, 16)            64000
#
#  conv1d (Conv1D)             (None, 46, 128)           10368
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense_2 (Dense)             (None, 6)                 774
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 75149 (293.55 KB)
# Trainable params: 75149 (293.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 1684/1684 [==============================] - 19s 10ms/step - loss: 0.4339 - accuracy: 0.7749 - val_loss: 0.3468 - val_accuracy: 0.8335
# Epoch 2/20
# 1684/1684 [==============================] - 16s 9ms/step - loss: 0.2937 - accuracy: 0.8602 - val_loss: 0.3121 - val_accuracy: 0.8549
# Epoch 3/20
# 1684/1684 [==============================] - 17s 10ms/step - loss: 0.2423 - accuracy: 0.8825 - val_loss: 0.3023 - val_accuracy: 0.8624
# Epoch 4/20
# 1684/1684 [==============================] - 15s 9ms/step - loss: 0.2070 - accuracy: 0.8970 - val_loss: 0.3100 - val_accuracy: 0.8593
# Epoch 5/20
# 1684/1684 [==============================] - 15s 9ms/step - loss: 0.1828 - accuracy: 0.9083 - val_loss: 0.3181 - val_accuracy: 0.8639
# Epoch 6/20
# 1684/1684 [==============================] - 15s 9ms/step - loss: 0.1654 - accuracy: 0.9144 - val_loss: 0.3354 - val_accuracy: 0.8660
# Epoch 7/20
# 1684/1684 [==============================] - 16s 9ms/step - loss: 0.1510 - accuracy: 0.9220 - val_loss: 0.3472 - val_accuracy: 0.8665
# Epoch 8/20
# 1684/1684 [==============================] - 17s 10ms/step - loss: 0.1413 - accuracy: 0.9244 - val_loss: 0.3750 - val_accuracy: 0.8627
# Epoch 9/20
# 1684/1684 [==============================] - 17s 10ms/step - loss: 0.1344 - accuracy: 0.9282 - val_loss: 0.3756 - val_accuracy: 0.8671
# Epoch 10/20
# 1684/1684 [==============================] - 15s 9ms/step - loss: 0.1266 - accuracy: 0.9314 - val_loss: 0.4120 - val_accuracy: 0.8599
# Epoch 11/20
# 1684/1684 [==============================] - 15s 9ms/step - loss: 0.1212 - accuracy: 0.9333 - val_loss: 0.4141 - val_accuracy: 0.8621
# Epoch 12/20
# 1684/1684 [==============================] - 17s 10ms/step - loss: 0.1169 - accuracy: 0.9362 - val_loss: 0.4210 - val_accuracy: 0.8688
# Epoch 13/20
# 1684/1684 [==============================] - 17s 10ms/step - loss: 0.1132 - accuracy: 0.9377 - val_loss: 0.4574 - val_accuracy: 0.8667
# Epoch 14/20
# 1684/1684 [==============================] - 15s 9ms/step - loss: 0.1102 - accuracy: 0.9385 - val_loss: 0.4532 - val_accuracy: 0.8634
# Epoch 15/20
# 1684/1684 [==============================] - 16s 9ms/step - loss: 0.1078 - accuracy: 0.9381 - val_loss: 0.4632 - val_accuracy: 0.8658
# Epoch 16/20
# 1684/1684 [==============================] - 15s 9ms/step - loss: 0.1050 - accuracy: 0.9397 - val_loss: 0.4832 - val_accuracy: 0.8638
# Epoch 17/20
# 1684/1684 [==============================] - 15s 9ms/step - loss: 0.1043 - accuracy: 0.9394 - val_loss: 0.4738 - val_accuracy: 0.8601
# Epoch 18/20
# 1684/1684 [==============================] - 17s 10ms/step - loss: 0.1022 - accuracy: 0.9410 - val_loss: 0.4892 - val_accuracy: 0.8597
# Epoch 19/20
# 1684/1684 [==============================] - 15s 9ms/step - loss: 0.0994 - accuracy: 0.9412 - val_loss: 0.5095 - val_accuracy: 0.8610
# Epoch 20/20
# 1684/1684 [==============================] - 18s 10ms/step - loss: 0.0988 - accuracy: 0.9422 - val_loss: 0.5216 - val_accuracy: 0.8608
# 1/1 [==============================] - 0s 140ms/step
# I loved this movie
# [0.9999962]
#
# that was the worst movie I've ever seen
# [2.2174177e-06]
#
# too much violence even for a bond film
# [2.4207994e-08]
#
# a captivating recounting of a cherished myth
# [1.]

# %% [markdown]
# ### Use a GRU

# %%
model_gru = keras.models.Sequential([
    keras.layers.Embedding(vocab_size, embedding_dim, input_length = max_length),
    keras.layers.Bidirectional(keras.layers.GRU(32)),
    keras.layers.Dense(6, activation = 'relu'),
    keras.layers.Dense(1, activation = 'sigmoid')
])
model_gru.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
# Epoch 17/20
# 1684/1684 [==============================] - 88s 52ms/step - loss: 0.1518 - accuracy: 0.9154 - val_loss: 0.4421 - val_accuracy: 0.8567
# Epoch 18/20
# 1684/1684 [==============================] - 87s 52ms/step - loss: 0.1472 - accuracy: 0.9170 - val_loss: 0.4762 - val_accuracy: 0.8531
# Epoch 19/20
# 1684/1684 [==============================] - 88s 52ms/step - loss: 0.1430 - accuracy: 0.9178 - val_loss: 0.4944 - val_accuracy: 0.8575
# Epoch 20/20
# 1684/1684 [==============================] - 89s 53ms/step - loss: 0.1395 - accuracy: 0.9209 - val_loss: 0.4847 - val_accuracy: 0.8576
# 1/1 [==============================] - 1s 1s/step
# I loved this movie
# [0.9999895]
#
# that was the worst movie I've ever seen
# [1.0480063e-05]
#
# too much violence even for a bond film
# [0.00044132]
#
# a captivating recounting of a cherished myth
# [0.9999992]

# %% [markdown]
# ### Use a bidirectional LSTM

# %%
model_bidi_lstm = keras.models.Sequential([
    keras.layers.Embedding(vocab_size, embedding_dim, input_length = max_length),
    keras.layers.Bidirectional(keras.layers.LSTM(embedding_dim)),
    keras.layers.Dense(6, activation = 'relu'),
    keras.layers.Dense(1, activation = 'sigmoid')
])
model_bidi_lstm.compile(loss = keras.losses.BinaryCrossentropy(),
             optimizer = keras.optimizers.Adam(),
             metrics = ['accuracy'])
fit_model_and_show_results(model_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional_5 (Bidirecti  (None, 32)                4224
#  onal)
#
#  dense_12 (Dense)            (None, 6)                 198
#
#  dense_13 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 68429 (267.30 KB)
# Trainable params: 68429 (267.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 1684/1684 [==============================] - 57s 31ms/step - loss: 0.4526 - accuracy: 0.7671 - val_loss: 0.3802 - val_accuracy: 0.8163
# Epoch 2/20
# 1684/1684 [==============================] - 50s 29ms/step - loss: 0.3413 - accuracy: 0.8367 - val_loss: 0.3571 - val_accuracy: 0.8344
# Epoch 3/20
# 1684/1684 [==============================] - 49s 29ms/step - loss: 0.3156 - accuracy: 0.8480 - val_loss: 0.3356 - val_accuracy: 0.8419
# Epoch 4/20
# 1684/1684 [==============================] - 49s 29ms/step - loss: 0.2902 - accuracy: 0.8591 - val_loss: 0.3290 - val_accuracy: 0.8465
# Epoch 5/20
# 1684/1684 [==============================] - 50s 29ms/step - loss: 0.2642 - accuracy: 0.8709 - val_loss: 0.3295 - val_accuracy: 0.8392
# Epoch 6/20
# 1684/1684 [==============================] - 50s 30ms/step - loss: 0.2432 - accuracy: 0.8796 - val_loss: 0.3213 - val_accuracy: 0.8526
# Epoch 7/20
# 1684/1684 [==============================] - 51s 30ms/step - loss: 0.2271 - accuracy: 0.8863 - val_loss: 0.3149 - val_accuracy: 0.8573
# Epoch 8/20
# 1684/1684 [==============================] - 50s 30ms/step - loss: 0.2137 - accuracy: 0.8901 - val_loss: 0.3274 - val_accuracy: 0.8491
# Epoch 9/20
# 1684/1684 [==============================] - 55s 33ms/step - loss: 0.2013 - accuracy: 0.8965 - val_loss: 0.3325 - val_accuracy: 0.8539
# Epoch 10/20
# 1684/1684 [==============================] - 56s 33ms/step - loss: 0.1899 - accuracy: 0.9006 - val_loss: 0.3405 - val_accuracy: 0.8546
# Epoch 11/20
# 1684/1684 [==============================] - 56s 33ms/step - loss: 0.1800 - accuracy: 0.9041 - val_loss: 0.3498 - val_accuracy: 0.8589
# Epoch 12/20
# 1684/1684 [==============================] - 56s 34ms/step - loss: 0.1730 - accuracy: 0.9088 - val_loss: 0.3541 - val_accuracy: 0.8585
# Epoch 13/20
# 1684/1684 [==============================] - 57s 34ms/step - loss: 0.1634 - accuracy: 0.9133 - val_loss: 0.3682 - val_accuracy: 0.8538
# Epoch 14/20
# 1684/1684 [==============================] - 57s 34ms/step - loss: 0.1581 - accuracy: 0.9155 - val_loss: 0.3962 - val_accuracy: 0.8550
# Epoch 15/20
# 1684/1684 [==============================] - 55s 33ms/step - loss: 0.1512 - accuracy: 0.9183 - val_loss: 0.3891 - val_accuracy: 0.8572
# Epoch 16/20
# 1684/1684 [==============================] - 57s 34ms/step - loss: 0.1460 - accuracy: 0.9207 - val_loss: 0.4095 - val_accuracy: 0.8554
# Epoch 17/20
# 1684/1684 [==============================] - 58s 34ms/step - loss: 0.1406 - accuracy: 0.9224 - val_loss: 0.4236 - val_accuracy: 0.8545
# Epoch 18/20
# 1684/1684 [==============================] - 57s 34ms/step - loss: 0.1402 - accuracy: 0.9223 - val_loss: 0.4200 - val_accuracy: 0.8598
# Epoch 19/20
# 1684/1684 [==============================] - 56s 33ms/step - loss: 0.1329 - accuracy: 0.9263 - val_loss: 0.4559 - val_accuracy: 0.8550
# Epoch 20/20
# 1684/1684 [==============================] - 61s 36ms/step - loss: 0.1303 - accuracy: 0.9279 - val_loss: 0.4559 - val_accuracy: 0.8612
# 1/1 [==============================] - 1s 1s/step
# I loved this movie
# [0.9999778]
#
# that was the worst movie I've ever seen
# [0.00120205]
#
# too much violence even for a bond film
# [0.00042375]
#
# a captivating recounting of a cherished myth
# [0.99983513]

# %% [markdown]
# ### Use multiple bidirectional LSTMs

# %%
model_mult_bidi_lstm = keras.Sequential([
    keras.layers.Embedding(vocab_size, embedding_dim, input_length = max_length),
    keras.layers.Bidirectional(keras.layers.LSTM(embedding_dim,
                                                return_sequences = True)),
    keras.layers.Bidirectional(keras.layers.LSTM(embedding_dim)),
    keras.layers.Dense(6, activation = 'relu'),
    keras.layers.Dense(1, activation = 'sigmoid')
])
model_mult_bidi_lstm.compile(loss = keras.losses.BinaryCrossentropy(),
             optimizer = keras.optimizers.Adam(),
             metrics = ['accuracy'])
fit_model_and_show_results(model_mult_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional_2 (Bidirecti  (None, 50, 32)            4224
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 32)                6272
#  onal)
#
#  dense_8 (Dense)             (None, 6)                 198
#
#  dense_9 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params:
# 1684/1684 [==============================] - 96s 57ms/step - loss: 0.1332 - accuracy: 0.9231 - val_loss: 0.4646 - val_accuracy: 0.8542
# Epoch 20/20
# 1684/1684 [==============================] - 96s 57ms/step - loss: 0.1302 - accuracy: 0.9257 - val_loss: 0.4461 - val_accuracy: 0.8575
# 1/1 [==============================] - 2s 2s/step
# I loved this movie
# [0.9998078]
#
# that was the worst movie I've ever seen
# [0.00068981]
#
# too much violence even for a bond film
# [0.00042672]
#
# a captivating recounting of a cherished myth
# [0.9995221]

# %% [markdown]
# ### Try some more reviews

# %%
review1 = """I loved this movie"""
review2 = """that was the worst movie I've ever seen"""
review3 = """too much violence even for a bond film"""
review4 = """a captivating recounting of a cherished myth"""
review5 = """I saw this movie yesterday and I was feeling low to start with,
but it was such a wonderful movie that it lifted my spirits and brightened
my day, you can\'t go wrong with a movie with Whoopi Goldberg in it"""
review6 = """I don\'t understand why it received an oscar recommendation
for best movie, it was long and boring"""
review7 = """the scenery was magnificent, the CGI of the dogs was so realistic I
thought they were played by real dogs even though they talked!"""
review8 = """The ending was so sad and yet so uplifting at the same time.
I'm looking for an excuse to see it again"""
review9 = """I had expected so much more from a movie made by the director
who made my most favourite movie ever, I was very disappointed in the tedious story"""
review10 = """I wish I could watch this movie every day for the rest of my life"""
review11 = """I did not love the movie"""
review12 = """The movie was good, however the ending was soo boring"""
review13 = """Exceeded my expectation"""
review14a = """The movie is overrated"""
review14b = """The movie is underated"""
review15a = """Wouldn't recommend"""
review15b = """would not recommend"""
review16 = """The best so far"""
review17 = """Waste of time!!!"""
review18 = """Not bad"""


more_reviews = [review1, review2, review3, review4, review5, review6, review7,
              review8, review9, review10, review11, review12, review13, review14a,
                review14b, review15a, review15b, review16, review17, review18]

# %%
print("==" * 15, "\nEmbeddings only:\n", "==" * 15)
predict_reviews(model, more_reviews)
print("==" * 15, "\nWith CNN:\n", "==" * 15)
predict_reviews(model_cnn, more_reviews)
print("==" * 15, "\nWith GRU:\n", "==" * 15)
predict_reviews(model_gru, more_reviews)
print("==" * 15, "\nWith bidirectional LSTM:\n", "==" * 15)
predict_reviews(model_bidi_lstm, more_reviews)
print("==" * 15, "\nWith multiple bidirectional LSTM:\n", "==" * 15)
predict_reviews(model_mult_bidi_lstm, more_reviews)
# Out:
# ==============================
# Embeddings only:
#  ==============================
# 1/1 [==============================] - 0s 21ms/step
# I loved this movie
# [0.9882387]
#
# that was the worst movie I've ever seen
# [0.01604736]
#
# too much violence even for a bond film
# [0.03413291]
#
# a captivating recounting of a cherished myth
# [0.98885965]
#
# I saw this movie yesterday and I was feeling low to start with,
# but it was such a wonderful movie that it lifted my spirits and brightened
# my day, you can't go wrong with a movie with Whoopi Goldberg in it
# [0.99931496]
#
# I don't understand why it received an oscar recommendation
# for best movie, it was long and boring
# [0.9928445]
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
# thought they were played by real dogs even though they talked!
# [0.07362157]
#
# The ending was so sad and yet so uplifting at the same time.
# I'm looking for an excuse to see it again
# [0.68808824]
#
# I had expected so much more from a movie made by the director
# who made my most favourite movie ever, I was very disappointed in the tedious story
# [0.00585316]
#
# I wish I could watch this movie every day for the rest of my life
# [0.5960264]
#
# I did not love the movie
# [0.62565446]
#
# The movie was good, however the ending was soo boring
# [0.05380076]
#
# Exceeded my expectation
# [0.89526254]
#
# The movie is overrated
# [0.75686216]
#
# The movie is underated
# [0.75686216]
#
# Wouldn't recommend
# [0.7748502]
#
# would not recommend
# [0.11502182]
#
# The best so far
# [0.94565135]
#
# Waste of time!!!
# [0.02666231]
#
# Not bad
# [0.08014549]
#
# ==============================
# With CNN:
#  ==============================
# 1/1 [==============================] - 0s 22ms/step
# I loved this movie
# [0.9999962]
#
# that was the worst movie I've ever seen
# [2.2174177e-06]
#
# too much violence even for a bond film
# [2.4207994e-08]
#
# a captivating recounting of a cherished myth
# [1.]
#
# I saw this movie yesterday and I was feeling low to start with,
# but it was such a wonderful movie that it lifted my spirits and brightened
# my day, you can't go wrong with a movie with Whoopi Goldberg in it
# [1.]
#
# I don't understand why it received an oscar recommendation
# for best movie, it was long and boring
# [1.]
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
# thought they were played by real dogs even though they talked!
# [0.00016038]
#
# The ending was so sad and yet so uplifting at the same time.
# I'm looking for an excuse to see it again
# [0.9855821]
#
# I had expected so much more from a movie made by the director
# who made my most favourite movie ever, I was very disappointed in the tedious story
# [0.00017195]
#
# I wish I could watch this movie every day for the rest of my life
# [0.20293109]
#
# I did not love the movie
# [0.00881483]
#
# The movie was good, however the ending was soo boring
# [0.99999654]
#
# Exceeded my expectation
# [0.9999964]
#
# The movie is overrated
# [0.03295316]
#
# The movie is underated
# [0.03295316]
#
# Wouldn't recommend
# [0.9899751]
#
# would not recommend
# [0.01542552]
#
# The best so far
# [0.99975723]
#
# Waste of time!!!
# [0.0042778]
#
# Not bad
# [0.21531118]
#
# ==============================
# With GRU:
#  ==============================
# 1/1 [==============================] - 0s 24ms/step
# I loved this movie
# [0.9999895]
#
# that was the worst movie I've ever seen
# [1.0480064e-05]
#
# too much violence even for a bond film
# [0.00044132]
#
# a captivating recounting of a cherished myth
# [0.9999992]
#
# I saw this movie yesterday and I was feeling low to start with,
# but it was such a wonderful movie that it lifted my spirits and brightened
# my day, you can't go wrong with a movie with Whoopi Goldberg in it
# [0.99999374]
#
# I don't understand why it received an oscar recommendation
# for best movie, it was long and boring
# [0.8116947]
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
# thought they were played by real dogs even though they talked!
# [0.04375956]
#
# The ending was so sad and yet so uplifting at the same time.
# I'm looking for an excuse to see it again
# [0.9999993]
#
# I had expected so much more from a movie made by the director
# who made my most favourite movie ever, I was very disappointed in the tedious story
# [0.00011396]
#
# I wish I could watch this movie every day for the rest of my life
# [0.12032869]
#
# I did not love the movie
# [0.02385737]
#
# The movie was good, however the ending was soo boring
# [0.12115332]
#
# Exceeded my expectation
# [0.99976104]
#
# The movie is overrated
# [0.22821762]
#
# The movie is underated
# [0.22821762]
#
# Wouldn't recommend
# [0.98120475]
#
# would not recommend
# [0.00016653]
#
# The best so far
# [0.9894724]
#
# Waste of time!!!
# [0.00081568]
#
# Not bad
# [0.5837074]
#
# ==============================
# With bidirectional LSTM:
#  ==============================
# 1/1 [==============================] - 0s 27ms/step
# I loved this movie
# [0.9999778]
#
# that was the worst movie I've ever seen
# [0.00120205]
#
# too much violence even for a bond film
# [0.00042375]
#
# a captivating recounting of a cherished myth
# [0.99983513]
#
# I saw this movie yesterday and I was feeling low to start with,
# but it was such a wonderful movie that it lifted my spirits and brightened
# my day, you can't go wrong with a movie with Whoopi Goldberg in it
# [0.9996388]
#
# I don't understand why it received an oscar recommendation
# for best movie, it was long and boring
# [0.8644184]
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
# thought they were played by real dogs even though they talked!
# [0.9999596]
#
# The ending was so sad and yet so uplifting at the same time.
# I'm looking for an excuse to see it again
# [0.00193643]
#
# I had expected so much more from a movie made by the director
# who made my most favourite movie ever, I was very disappointed in the tedious story
# [0.00051896]
#
# I wish I could watch this movie every day for the rest of my life
# [0.01258723]
#
# I did not love the movie
# [0.17153502]
#
# The movie was good, however the ending was soo boring
# [0.00473574]
#
# Exceeded my expectation
# [0.9997465]
#
# The movie is overrated
# [0.09285966]
#
# The movie is underated
# [0.09285966]
#
# Wouldn't recommend
# [0.9656904]
#
# would not recommend
# [0.04005639]
#
# The best so far
# [0.9928092]
#
# Waste of time!!!
# [0.00446027]
#
# Not bad
# [0.7945293]
#
# ==============================
# With multiple bidirectional LSTM:
#  ==============================
# 1/1 [==============================] - 0s 31ms/step
# I loved this movie
# [0.9998078]
#
# that was the worst movie I've ever seen
# [0.00068981]
#
# too much violence even for a bond film
# [0.00042672]
#
# a captivating recounting of a cherished myth
# [0.9995221]
#
# I saw this movie yesterday and I was feeling low to start with,
# but it was such a wonderful movie that it lifted my spirits and brightened
# my day, you can't go wrong with a movie with Whoopi Goldberg in it
# [0.9996935]
#
# I don't understand why it received an oscar recommendation
# for best movie, it was long and boring
# [6.935167e-05]
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
# thought they were played by real dogs even though they talked!
# [0.00044868]
#
# The ending was so sad and yet so uplifting at the same time.
# I'm looking for an excuse to see it again
# [0.9999535]
#
# I had expected so much more from a movie made by the director
# who made my most favourite movie ever, I was very disappointed in the tedious story
# [4.7049693e-05]
#
# I wish I could watch this movie every day for the rest of my life
# [0.44954556]
#
# I did not love the movie
# [0.01706946]
#
# The movie was good, however the ending was soo boring
# [0.00160325]
#
# Exceeded my expectation
# [0.99830925]
#
# The movie is overrated
# [0.41114488]
#
# The movie is underated
# [0.41114488]
#
# Wouldn't recommend
# [0.9924209]
#
# would not recommend
# [0.00706778]
#
# The best so far
# [0.99964637]
#
# Waste of time!!!
# [0.00120816]
#
# Not bad
# [0.68592095]
